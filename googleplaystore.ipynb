# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('googleplaystore.csv')
df.head(40)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# 11            Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4
# 12                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# 13                              Mandala Coloring Book  ART_AND_DESIGN     4.6
# 14    3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN     4.4
# 15                    Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2
# 16       Photo Designer - Write your name with shapes  ART_AND_DESIGN     4.7
# 17                           350 Diy Room Decor Ideas  ART_AND_DESIGN     4.5
# 18                      FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 19                                       ibis Paint X  ART_AND_DESIGN     4.6
# 20                        Logo Maker - Small Business  ART_AND_DESIGN     4.0
# 21          Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1
# 22            Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN     4.7
# 23                             Mcqueen Coloring pages  ART_AND_DESIGN     NaN
# 24                        HD Mickey Minnie Wallpapers  ART_AND_DESIGN     4.7
# 25                         Harley Quinn wallpapers HD  ART_AND_DESIGN     4.8
# 26                      Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7
# 27                              Animated Photo Editor  ART_AND_DESIGN     4.1
# 28                              Pencil Sketch Drawing  ART_AND_DESIGN     3.9
# 29                    Easy Realistic Drawing Tutorial  ART_AND_DESIGN     4.1
# 30                     Pink Silver Bow Keyboard Theme  ART_AND_DESIGN     4.2
# 31                                  Art Drawing Ideas  ART_AND_DESIGN     4.1
# 32                          Anime Manga Coloring Book  ART_AND_DESIGN     4.5
# 33                                 Easy Origami Ideas  ART_AND_DESIGN     4.2
# 34                                    I Creative Idea  ART_AND_DESIGN     4.7
# 35                   How to draw Ladybug and Cat Noir  ART_AND_DESIGN     3.8
# 36     UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN     4.7
# 37                                 Floor Plan Creator  ART_AND_DESIGN     4.1
# 38                     PIP Camera - PIP Collage Maker  ART_AND_DESIGN     4.7
# 39      How To Color Disney Princess - Coloring Pages  ART_AND_DESIGN     4.0
#
#    Reviews                Size     Installs  Type Price Content_Rating  \
# 0      159                 19M      10,000+  Free     0       Everyone
# 1      967                 14M     500,000+  Free     0       Everyone
# 2    87510                8.7M   5,000,000+  Free     0       Everyone
# 3   215644                 25M  50,000,000+  Free     0           Teen
# 4      967                2.8M     100,000+  Free     0       Everyone
# 5      167                5.6M      50,000+  Free     0       Everyone
# 6      178                 19M      50,000+  Free     0       Everyone
# 7    36815                 29M   1,000,000+  Free     0       Everyone
# 8    13791                 33M   1,000,000+  Free     0       Everyone
# 9      121                3.1M      10,000+  Free     0       Everyone
# 10   13880                 28M   1,000,000+  Free     0       Everyone
# 11    8788                 12M   1,000,000+  Free     0       Everyone
# 12   44829                 20M  10,000,000+  Free     0           Teen
# 13    4326                 21M     100,000+  Free     0       Everyone
# 14    1518                 37M     100,000+  Free     0       Everyone
# 15      55                2.7M       5,000+  Free     0       Everyone
# 16    3632                5.5M     500,000+  Free     0       Everyone
# 17      27                 17M      10,000+  Free     0       Everyone
# 18  194216                 39M   5,000,000+  Free     0       Everyone
# 19  224399                 31M  10,000,000+  Free     0       Everyone
# 20     450                 14M     100,000+  Free     0       Everyone
# 21     654                 12M     100,000+  Free     0       Everyone
# 22    7699                4.2M     500,000+  Free     0   Everyone_10+
# 23      61                7.0M     100,000+  Free     0       Everyone
# 24     118                 23M      50,000+  Free     0       Everyone
# 25     192                6.0M      10,000+  Free     0       Everyone
# 26   20260                 25M     500,000+  Free     0       Everyone
# 27     203                6.1M     100,000+  Free     0       Everyone
# 28     136                4.6M      10,000+  Free     0       Everyone
# 29     223                4.2M     100,000+  Free     0       Everyone
# 30    1120                9.2M     100,000+  Free     0       Everyone
# 31     227                5.2M      50,000+  Free     0       Everyone
# 32    5035                 11M     100,000+  Free     0       Everyone
# 33    1015                 11M     100,000+  Free     0       Everyone
# 34     353                4.2M      10,000+  Free     0           Teen
# 35     564                9.2M     100,000+  Free     0       Everyone
# 36    8145                 24M     500,000+  Free     0       Everyone
# 37   36639  Varies with device   5,000,000+  Free     0       Everyone
# 38     158                 11M      10,000+  Free     0       Everyone
# 39     591                9.4M     500,000+  Free     0       Everyone
#
#                              Genres        Last Updated         Current Ver  \
# 0                      Art_&_Design     January 7, 2018               1.0.0
# 1         Art_&_Design_Pretend_Play    January 15, 2018               2.0.0
# 2                      Art_&_Design      August 1, 2018               1.2.4
# 3                      Art_&_Design        June 8, 2018  Varies with device
# 4           Art_&_Design_Creativity       June 20, 2018                 1.1
# 5                      Art_&_Design      March 26, 2017                   1
# 6                      Art_&_Design      April 26, 2018                 1.1
# 7                      Art_&_Design       June 14, 2018            6.1.61.1
# 8                      Art_&_Design  September 20, 2017               2.9.2
# 9           Art_&_Design_Creativity        July 3, 2018                 2.8
# 10                     Art_&_Design    October 27, 2017               1.0.4
# 11                     Art_&_Design       July 31, 2018              1.0.15
# 12                     Art_&_Design       April 2, 2018                 3.8
# 13                     Art_&_Design       June 26, 2018               1.0.4
# 14                     Art_&_Design      August 3, 2018               1.2.3
# 15                     Art_&_Design        June 6, 2018                 NaN
# 16                     Art_&_Design       July 31, 2018                 3.1
# 17                     Art_&_Design    November 7, 2017                   1
# 18                     Art_&_Design      August 3, 2018               2.2.5
# 19                     Art_&_Design       July 30, 2018               5.5.4
# 20                     Art_&_Design      April 20, 2018                   4
# 21                     Art_&_Design      March 20, 2018                 1.1
# 22                     Art_&_Design       July 12, 2018             2.2.6.2
# 23  Art_&_Design_Action_&_Adventure       March 7, 2018               1.0.0
# 24                     Art_&_Design        July 7, 2018               1.1.3
# 25                     Art_&_Design      April 25, 2018                 1.5
# 26          Art_&_Design_Creativity    October 11, 2017               1.0.8
# 27                     Art_&_Design      March 21, 2018                1.03
# 28                     Art_&_Design       July 12, 2018                   6
# 29                     Art_&_Design     August 22, 2017                   1
# 30                     Art_&_Design       July 12, 2018         6.7.12.2018
# 31                     Art_&_Design        May 31, 2018                 1.2
# 32                     Art_&_Design       July 19, 2018                 2.2
# 33                     Art_&_Design     January 6, 2018               1.1.0
# 34                     Art_&_Design      April 27, 2018                 1.6
# 35                     Art_&_Design       July 11, 2018                 2.1
# 36          Art_&_Design_Creativity      August 2, 2018               1.0.9
# 37                     Art_&_Design       July 14, 2018  Varies with device
# 38                     Art_&_Design   November 29, 2017                 1.3
# 39                     Art_&_Design      March 31, 2018                   1
#
#      Android Ver
# 0   4.0.3 and up
# 1   4.0.3 and up
# 2   4.0.3 and up
# 3     4.2 and up
# 4     4.4 and up
# 5     2.3 and up
# 6   4.0.3 and up
# 7     4.2 and up
# 8     3.0 and up
# 9   4.0.3 and up
# 10    4.1 and up
# 11    4.0 and up
# 12    4.1 and up
# 13    4.4 and up
# 14    2.3 and up
# 15    4.2 and up
# 16    4.1 and up
# 17    2.3 and up
# 18  4.0.3 and up
# 19    4.1 and up
# 20    4.1 and up
# 21  4.0.3 and up
# 22  4.0.3 and up
# 23    4.1 and up
# 24    4.1 and up
# 25    3.0 and up
# 26  4.0.3 and up
# 27  4.0.3 and up
# 28    2.3 and up
# 29    2.3 and up
# 30  4.0.3 and up
# 31    2.3 and up
# 32    4.0 and up
# 33    4.1 and up
# 34    4.1 and up
# 35    4.1 and up
# 36    4.4 and up
# 37  2.3.3 and up
# 38  4.0.3 and up
# 39    4.0 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content_Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.Price.value_counts()[:5]
# Out:
# Price
# 0        8715
# $2.99     114
# $0.99     106
# $4.99      70
# $1.99      59
# Name: count, dtype: int64

# %%
df.Price=df.Price.map(lambda x:0 if x=='0' else float(x[1:]))

# %%
df.Price.dtypes
# Out:
# dtype('float64')

# %%
df.Reviews=df.Reviews.astype("int32")

# %%
df.Reviews.dtypes
# Out:
# dtype('int32')

# %%
df.Reviews.describe()
# Out:
# count    9.360000e+03
# mean     5.143767e+05
# std      3.145023e+06
# min      1.000000e+00
# 25%      1.867500e+02
# 50%      5.955000e+03
# 75%      8.162750e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
df.Reviews.describe()
# Out:
# count    9.360000e+03
# mean     5.143767e+05
# std      3.145023e+06
# min      1.000000e+00
# 25%      1.867500e+02
# 50%      5.955000e+03
# 75%      8.162750e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
df.Installs.value_counts()
# Out:
# Installs
# 1,000,000+        1576
# 10,000,000+       1252
# 100,000+          1150
# 10,000+           1009
# 5,000,000+         752
# 1,000+             712
# 500,000+           537
# 50,000+            466
# 5,000+             431
# 100,000,000+       409
# 100+               309
# 50,000,000+        289
# 500+               201
# 500,000,000+        72
# 10+                 69
# 1,000,000,000+      58
# 50+                 56
# 5+                   9
# 1+                   3
# Name: count, dtype: int64

# %%
def clean_installs(val):
    return int(val.replace(",","").replace("+",""))

# %%
df.Installs=df.Installs.map(clean_installs)

# %%
df.Installs.value_counts()
# Out:
# Installs
# 1000000       1576
# 10000000      1252
# 100000        1150
# 10000         1009
# 5000000        752
# 1000           712
# 500000         537
# 50000          466
# 5000           431
# 100000000      409
# 100            309
# 50000000       289
# 500            201
# 500000000       72
# 10              69
# 1000000000      58
# 50              56
# 5                9
# 1                3
# Name: count, dtype: int64

# %%
df.Installs.describe()
# Out:
# count    9.360000e+03
# mean     1.790875e+07
# std      9.126637e+07
# min      1.000000e+00
# 25%      1.000000e+04
# 50%      5.000000e+05
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %%
def change_Size(Size):
    if 'M' in Size:
        x=Size[:-1]
        x=float(x)*1000
        return(x)
    elif 'k' == Size[:-1]:
        x= Size[:-1]
        x=float(x)
        return(x)
    else:
        return None

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df["Size"]= df["Size"].map(change_Size)

# %%
df.Size.dtype
# Out:
# dtype('float64')

# %%
df.Size.isnull().sum()
# Out:
# 1894

# %%
df.head(40)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# 11            Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4
# 12                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# 13                              Mandala Coloring Book  ART_AND_DESIGN     4.6
# 14    3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN     4.4
# 16       Photo Designer - Write your name with shapes  ART_AND_DESIGN     4.7
# 17                           350 Diy Room Decor Ideas  ART_AND_DESIGN     4.5
# 18                      FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 19                                       ibis Paint X  ART_AND_DESIGN     4.6
# 20                        Logo Maker - Small Business  ART_AND_DESIGN     4.0
# 21          Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1
# 22            Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN     4.7
# 24                        HD Mickey Minnie Wallpapers  ART_AND_DESIGN     4.7
# 25                         Harley Quinn wallpapers HD  ART_AND_DESIGN     4.8
# 26                      Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7
# 27                              Animated Photo Editor  ART_AND_DESIGN     4.1
# 28                              Pencil Sketch Drawing  ART_AND_DESIGN     3.9
# 29                    Easy Realistic Drawing Tutorial  ART_AND_DESIGN     4.1
# 30                     Pink Silver Bow Keyboard Theme  ART_AND_DESIGN     4.2
# 31                                  Art Drawing Ideas  ART_AND_DESIGN     4.1
# 32                          Anime Manga Coloring Book  ART_AND_DESIGN     4.5
# 33                                 Easy Origami Ideas  ART_AND_DESIGN     4.2
# 34                                    I Creative Idea  ART_AND_DESIGN     4.7
# 35                   How to draw Ladybug and Cat Noir  ART_AND_DESIGN     3.8
# 36     UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN     4.7
# 37                                 Floor Plan Creator  ART_AND_DESIGN     4.1
# 38                     PIP Camera - PIP Collage Maker  ART_AND_DESIGN     4.7
# 39      How To Color Disney Princess - Coloring Pages  ART_AND_DESIGN     4.0
# 40                      Drawing Clothes Fashion Ideas  ART_AND_DESIGN     4.2
# 41                       Sad Poetry Photo Frames 2018  ART_AND_DESIGN     4.5
#
#     Reviews     Size  Installs  Type  Price Content_Rating  \
# 0       159  19000.0     10000  Free    0.0       Everyone
# 1       967  14000.0    500000  Free    0.0       Everyone
# 2     87510   8700.0   5000000  Free    0.0       Everyone
# 3    215644  25000.0  50000000  Free    0.0           Teen
# 4       967   2800.0    100000  Free    0.0       Everyone
# 5       167   5600.0     50000  Free    0.0       Everyone
# 6       178  19000.0     50000  Free    0.0       Everyone
# 7     36815  29000.0   1000000  Free    0.0       Everyone
# 8     13791  33000.0   1000000  Free    0.0       Everyone
# 9       121   3100.0     10000  Free    0.0       Everyone
# 10    13880  28000.0   1000000  Free    0.0       Everyone
# 11     8788  12000.0   1000000  Free    0.0       Everyone
# 12    44829  20000.0  10000000  Free    0.0           Teen
# 13     4326  21000.0    100000  Free    0.0       Everyone
# 14     1518  37000.0    100000  Free    0.0       Everyone
# 16     3632   5500.0    500000  Free    0.0       Everyone
# 17       27  17000.0     10000  Free    0.0       Everyone
# 18   194216  39000.0   5000000  Free    0.0       Everyone
# 19   224399  31000.0  10000000  Free    0.0       Everyone
# 20      450  14000.0    100000  Free    0.0       Everyone
# 21      654  12000.0    100000  Free    0.0       Everyone
# 22     7699   4200.0    500000  Free    0.0   Everyone_10+
# 24      118  23000.0     50000  Free    0.0       Everyone
# 25      192   6000.0     10000  Free    0.0       Everyone
# 26    20260  25000.0    500000  Free    0.0       Everyone
# 27      203   6100.0    100000  Free    0.0       Everyone
# 28      136   4600.0     10000  Free    0.0       Everyone
# 29      223   4200.0    100000  Free    0.0       Everyone
# 30     1120   9200.0    100000  Free    0.0       Everyone
# 31      227   5200.0     50000  Free    0.0       Everyone
# 32     5035  11000.0    100000  Free    0.0       Everyone
# 33     1015  11000.0    100000  Free    0.0       Everyone
# 34      353   4200.0     10000  Free    0.0           Teen
# 35      564   9200.0    100000  Free    0.0       Everyone
# 36     8145  24000.0    500000  Free    0.0       Everyone
# 37    36639      NaN   5000000  Free    0.0       Everyone
# 38      158  11000.0     10000  Free    0.0       Everyone
# 39      591   9400.0    500000  Free    0.0       Everyone
# 40      117  15000.0     10000  Free    0.0       Everyone
# 41      176  10000.0    100000  Free    0.0       Everyone
#
#                        Genres        Last Updated         Current Ver  \
# 0                Art_&_Design     January 7, 2018               1.0.0
# 1   Art_&_Design_Pretend_Play    January 15, 2018               2.0.0
# 2                Art_&_Design      August 1, 2018               1.2.4
# 3                Art_&_Design        June 8, 2018  Varies with device
# 4     Art_&_Design_Creativity       June 20, 2018                 1.1
# 5                Art_&_Design      March 26, 2017                   1
# 6                Art_&_Design      April 26, 2018                 1.1
# 7                Art_&_Design       June 14, 2018            6.1.61.1
# 8                Art_&_Design  September 20, 2017               2.9.2
# 9     Art_&_Design_Creativity        July 3, 2018                 2.8
# 10               Art_&_Design    October 27, 2017               1.0.4
# 11               Art_&_Design       July 31, 2018              1.0.15
# 12               Art_&_Design       April 2, 2018                 3.8
# 13               Art_&_Design       June 26, 2018               1.0.4
# 14               Art_&_Design      August 3, 2018               1.2.3
# 16               Art_&_Design       July 31, 2018                 3.1
# 17               Art_&_Design    November 7, 2017                   1
# 18               Art_&_Design      August 3, 2018               2.2.5
# 19               Art_&_Design       July 30, 2018               5.5.4
# 20               Art_&_Design      April 20, 2018                   4
# 21               Art_&_Design      March 20, 2018                 1.1
# 22               Art_&_Design       July 12, 2018             2.2.6.2
# 24               Art_&_Design        July 7, 2018               1.1.3
# 25               Art_&_Design      April 25, 2018                 1.5
# 26    Art_&_Design_Creativity    October 11, 2017               1.0.8
# 27               Art_&_Design      March 21, 2018                1.03
# 28               Art_&_Design       July 12, 2018                   6
# 29               Art_&_Design     August 22, 2017                   1
# 30               Art_&_Design       July 12, 2018         6.7.12.2018
# 31               Art_&_Design        May 31, 2018                 1.2
# 32               Art_&_Design       July 19, 2018                 2.2
# 33               Art_&_Design     January 6, 2018               1.1.0
# 34               Art_&_Design      April 27, 2018                 1.6
# 35               Art_&_Design       July 11, 2018                 2.1
# 36    Art_&_Design_Creativity      August 2, 2018               1.0.9
# 37               Art_&_Design       July 14, 2018  Varies with device
# 38               Art_&_Design   November 29, 2017                 1.3
# 39               Art_&_Design      March 31, 2018                   1
# 40               Art_&_Design       July 20, 2018               2.0.1
# 41               Art_&_Design       April 2, 2018                   1
#
#      Android Ver
# 0   4.0.3 and up
# 1   4.0.3 and up
# 2   4.0.3 and up
# 3     4.2 and up
# 4     4.4 and up
# 5     2.3 and up
# 6   4.0.3 and up
# 7     4.2 and up
# 8     3.0 and up
# 9   4.0.3 and up
# 10    4.1 and up
# 11    4.0 and up
# 12    4.1 and up
# 13    4.4 and up
# 14    2.3 and up
# 16    4.1 and up
# 17    2.3 and up
# 18  4.0.3 and up
# 19    4.1 and up
# 20    4.1 and up
# 21  4.0.3 and up
# 22  4.0.3 and up
# 24    4.1 and up
# 25    3.0 and up
# 26  4.0.3 and up
# 27  4.0.3 and up
# 28    2.3 and up
# 29    2.3 and up
# 30  4.0.3 and up
# 31    2.3 and up
# 32    4.0 and up
# 33    4.1 and up
# 34    4.1 and up
# 35    4.1 and up
# 36    4.4 and up
# 37  2.3.3 and up
# 38  4.0.3 and up
# 39    4.0 and up
# 40  4.0.3 and up
# 41  4.0.3 and up

# %%
df.Size.unique()
# Out:
# array([ 19000.,  14000.,   8700.,  25000.,   2800.,   5600.,  29000.,
#         33000.,   3100.,  28000.,  12000.,  20000.,  21000.,  37000.,
#          5500.,  17000.,  39000.,  31000.,   4200.,  23000.,   6000.,
#          6100.,   4600.,   9200.,   5200.,  11000.,  24000.,     nan,
#          9400.,  15000.,  10000.,   1200.,  26000.,   8000.,   7900.,
#         56000.,  57000.,  35000.,  54000.,   3600.,   5700.,   8600.,
#          2400.,  27000.,   2700.,   2500.,   7000.,  16000.,   3400.,
#          8900.,   3900.,   2900.,  38000.,  32000.,   5400.,  18000.,
#          1100.,   2200.,   4500.,   9800.,  52000.,   9000.,   6700.,
#         30000.,   2600.,   7100.,  22000.,   6400.,   3200.,   8200.,
#          4900.,   9500.,   5000.,   5900.,  13000.,  73000.,   6800.,
#          3500.,   4000.,   2300.,   2100.,  42000.,   9100.,  55000.,
#          7300.,   6500.,   1500.,   7500.,  51000.,  41000.,  48000.,
#          8500.,  46000.,   8300.,   4300.,   4700.,   3300.,  40000.,
#          7800.,   8800.,   6600.,   5100.,  61000.,  66000.,   8400.,
#          3700.,  44000.,   1600.,   6200.,  53000.,   1400.,   3000.,
#          7200.,   5800.,   3800.,   9600.,  45000.,  63000.,  49000.,
#         77000.,   4400.,  70000.,   9300.,   8100.,  36000.,   6900.,
#          7400.,  84000.,  97000.,   2000.,   1900.,   1800.,   5300.,
#         47000.,  76000.,   7600.,  59000.,   9700.,  78000.,  72000.,
#         43000.,   7700.,   6300.,  93000.,  65000.,  79000., 100000.,
#         58000.,  50000.,  68000.,  64000.,  34000.,  67000.,  60000.,
#         94000.,   9900.,  99000.,  95000.,  80000.,   1700.,  74000.,
#         62000.,  69000.,  75000.,  98000.,  85000.,  82000.,  96000.,
#         87000.,  71000.,  86000.,  91000.,  81000.,  92000.,  83000.,
#         88000.,   4800.,   1300.,   4100.,  89000.,  90000.,   1000.])

# %%
df.Size.fillna(method='ffill',inplace=True)
df.Size.isnull().sum()
# Out:
# 0

# %%
df.Rating.describe()
# Out:
# count    9360.000000
# mean        4.191838
# std         0.515263
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
len(df[df.Reviews>df.Installs])
# Out:
# 7

# %%
df1=df[df.Reviews<df.Installs].copy()
df1.shape
# Out:
# (9351, 13)

# %%
len(df[(df.Type=='Free')&(df.Price>0)])
# Out:
# 0

# %%
num=df.select_dtypes(include='number')

# %%
for i in num.columns:
    sns.boxplot(num[i])
    plt.show()

# %%
for i in num.columns:
    q1=num[i].quantile(0.25)
    
    q3=num[i].quantile(0.75)
    
    iqr=q3-q1
    
    UB=q3+1.5*iqr
    
    LB=q1-1.5*iqr
    num[i]=np.where(num[i]<LB,LB,num[i])
    num[i]=np.where(num[i]>UB,UB,num[i])

# %%
for i in num.columns:
    sns.boxplot(num[i])
    plt.show()

# %%
df.Rating.plot.hist()
plt.show()

# %%
df['Size'].plot.hist()
plt.show()

# %%
df=df[df.Reviews<=2000000]
df.shape
# Out:
# (8907, 13)

# %%
df.Installs.quantile([0.1,0.25,0.5,0.7,0.75,0.95,0.99])
# Out:
# 0.10         1000.0
# 0.25        10000.0
# 0.50       500000.0
# 0.70      1000000.0
# 0.75      5000000.0
# 0.95     10000000.0
# 0.99    100000000.0
# Name: Installs, dtype: float64

# %%
df['Installs'].plot.hist()
plt.show()

# %%
len(df[df.Installs >= 1000000000])
# Out:
# 6

# %%
df= df[df.Installs < 1000000000].copy() 
df.shape
# Out:
# (8901, 13)

# %%
sns.jointplot(data=df,x=df.Price,y= df.Rating)

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize=[8,6])
sns.boxplot(df['Content_Rating'],df.Rating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 plt.figure(figsize=[8,6])
# ----> 2 sns.boxplot(df['Content_Rating'],df.Rating)
#
# TypeError: boxplot() takes from 0 to 1 positional arguments but 2 were given

# %%
plt.figure(figsize=[18,6])
g=sns.boxplot(df.Category,df.Rating)
plt.xticks(rotation=90)

# %% [markdown]
# # preprocessing

# %%
df1=df.copy()

# %%
df1.skew()

# %%
df1.Installs=df1.Installs.apply(np.log1p)
df1.Reviews=df1.Reviews.apply(np.log1p)

# %%
df1.skew()

# %%
df1.drop(['App','Last Updated','Current Ver','Android Ver'],axis=1,inplace=True)
df1.shape

# %%
df1.head()

# %%
np.unique(df1.Category)

# %%
np.unique(df1.Genres)

# %%
df1.info()

# %%
  np.unique(df1.Type)
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df3=pd.get_dummies(df1,drop_first=True)

# %%
df3.head()
# Out:
#    Rating  Reviews     Size  Installs  Price  \
# 0     4.1      159  19000.0     10000    0.0
# 1     3.9      967  14000.0    500000    0.0
# 2     4.7    87510   8700.0   5000000    0.0
# 3     4.5   215644  25000.0  50000000    0.0
# 4     4.3      967   2800.0    100000    0.0
#
#    App_+Download 4 Instagram Twitter  App_.R  App_/u/app  App_058.ba  \
# 0                              False   False       False       False
# 1                              False   False       False       False
# 2                              False   False       False       False
# 3                              False   False       False       False
# 4                              False   False       False       False
#
#    App_1. FC Köln App  ...  Android Ver_5.0 - 6.0  Android Ver_5.0 - 8.0  \
# 0               False  ...                  False                  False
# 1               False  ...                  False                  False
# 2               False  ...                  False                  False
# 3               False  ...                  False                  False
# 4               False  ...                  False                  False
#
#    Android Ver_5.0 and up  Android Ver_5.1 and up  Android Ver_6.0 and up  \
# 0                   False                   False                   False
# 1                   False                   False                   False
# 2                   False                   False                   False
# 3                   False                   False                   False
# 4                   False                   False                   False
#
#    Android Ver_7.0 - 7.1.1  Android Ver_7.0 and up  Android Ver_7.1 and up  \
# 0                    False                   False                   False
# 1                    False                   False                   False
# 2                    False                   False                   False
# 3                    False                   False                   False
# 4                    False                   False                   False
#
#    Android Ver_8.0 and up  Android Ver_Varies with device
# 0                   False                           False
# 1                   False                           False
# 2                   False                           False
# 3                   False                           False
# 4                   False                           False
#
# [5 rows x 12256 columns]

# %%
df3.shape
# Out:
# (9351, 12256)

# %%
cols=['Category','Content_Ration','Genres']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.transfrom([cols])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 3
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le=LabelEncoder()
# ----> 3 le.transfrom([cols])
#
# AttributeError: 'LabelEncoder' object has no attribute 'transfrom'
